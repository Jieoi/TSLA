# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
import re
import numpy as np 
import matplotlib.dates as mdates

from utils import textkit as tk

# %% [markdown]
# ### 1. TSLA STOCK DATA PRICE

# %%
price_df = pd.read_csv("data/ingestion/price/us_stock_price_yahoo_finance_top10.csv")  
price_df = price_df[price_df['ticker']  == 'TSLA']
price_df
# Out:
#        Unnamed: 0            timestamp        open        high         low  \
# 26979       26979  2010-06-29 13:30:00    1.266667    1.666667    1.169333
# 26980       26980  2010-06-30 13:30:00    1.719333    2.028000    1.553333
# 26981       26981  2010-07-01 13:30:00    1.666667    1.728000    1.351333
# 26982       26982  2010-07-02 13:30:00    1.533333    1.540000    1.247333
# 26983       26983  2010-07-06 13:30:00    1.333333    1.333333    1.055333
# ...           ...                  ...         ...         ...         ...
# 30790       30790  2025-08-22 13:30:00  321.660004  340.250000  319.690002
# 30791       30791  2025-08-25 13:30:00  338.899994  349.529999  335.029999
# 30792       30792  2025-08-26 13:30:00  344.929993  351.899994  343.720001
# 30793       30793  2025-08-27 13:30:00  351.940002  355.390015  349.160004
# 30794       30794  2025-08-28 13:30:00  350.910004  353.549988  340.260010
#
# ...

# %%
price_df['timestamp'] = pd.to_datetime(price_df['timestamp'])
plt.figure(figsize=(10, 5)) 
ax = plt.gca() 

# Plot the data
ax.plot(price_df['timestamp'], price_df['adjclose'], 
        marker='o', 
        markersize=3, # Smaller markers for dense data
        linestyle='-', 
        color='blue', 
        linewidth=1.5)

# Axis Formatting
locator = mdates.AutoDateLocator(minticks=5, maxticks=10)
formatter = mdates.ConciseDateFormatter(locator)
ax.xaxis.set_major_locator(locator)
ax.xaxis.set_major_formatter(formatter)

plt.xticks(rotation=45, ha='right') 
ax.set_facecolor('white')
ax.grid(True, linestyle='--', alpha=0.6, color='gray') 
ax.set_axisbelow(True)

# Add titles and labels
plt.title('Adjusted Close Price Over Time', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Adjusted Close Price ($)', fontsize=12)

# Adjust layout to prevent labels from being cut off
plt.tight_layout() 

# Display the final plot
plt.show()

# %%
# Flagging (Increase/Decrease) base on T-1/3/5/7 price history

# sort chronologically by "datetime" column
price_df = price_df.sort_values('datetime').reset_index(drop=True)

# create the date flag
price_df['day_order'] = range(1, len(price_df) + 1)
price_df['day_order'] = range(1, len(price_df) + 1)

# create column for (T, T-1, T-3, T-5)
time_window = [1, 3, 5, 7]

# Generate lag adjclose dynamically
for lag in time_window:
    price_df[f'T_minus_{lag}_price'] = price_df['close'].shift(lag)
price_df['T_price'] = price_df['adjclose']

# Generate text flag (increase/decrease)
for lag in time_window:
    price_df[f'change_vs_T_minus_{lag}'] = np.where(
        price_df['T_price'] > price_df[f'T_minus_{lag}_price'], 1,
        np.where(price_df['T_price'] < price_df[f'T_minus_{lag}_price'], 0, 0)
    )

display(price_df.tail(10))
price_df.to_csv(r"data\process_data\price\TLSA_price_processed.csv")
# Out:
#       Unnamed: 0            timestamp        open        high         low  \
# 3806       30785  2025-08-15 13:30:00  337.660004  339.299988  327.019989
# 3807       30786  2025-08-18 13:30:00  329.619995  336.269989  329.589996
# 3808       30787  2025-08-19 13:30:00  335.790009  340.549988  327.850006
# 3809       30788  2025-08-20 13:30:00  329.220001  331.369995  314.600006
# 3810       30789  2025-08-21 13:30:00  322.079987  324.899994  318.679993
# 3811       30790  2025-08-22 13:30:00  321.660004  340.250000  319.690002
# 3812       30791  2025-08-25 13:30:00  338.899994  349.529999  335.029999
# 3813       30792  2025-08-26 13:30:00  344.929993  351.899994  343.720001
# 3814       30793  2025-08-27 13:30:00  351.940002  355.390015  349.160004
# 3815       30794  2025-08-28 13:30:00  350.910004  353.549988  340.260010
#
#            close    adjclose    volume  datetime  year  ...  day_order  \
# 3806  330.559998  330.559998  74319800  20250815  2025  ...       3807
# ...

# %% [markdown]
# ### 2. DATA NEWS

# %%
df = pd.read_csv("data/ingestion/news/nbc_articles_with_content_official.csv")

# %%
# Convert 'date' column to datetime objects
df["date"] = pd.to_datetime(df["date"], errors="coerce")

# Aggregate monthly counts for ALL years
monthly_counts = (
    df.set_index("date")
      .resample("MS") # 'MS' means Month Start
      .size()
)

# Get a list of unique years from the data
years = monthly_counts.index.year.unique()
n_years = len(years)

# Calculate the required grid size for the subplots
n_cols = int(np.ceil(np.sqrt(n_years)))
n_rows = int(np.ceil(n_years / n_cols))

# Create the figure and the grid of subplots
fig, axes = plt.subplots(
    nrows=n_rows,
    ncols=n_cols,
    figsize=(5 * n_cols, 4 * n_rows) # Adjust size as needed
)
axes = axes.flatten()

# Loop through each year and plot on a different subplot
for i, year in enumerate(years):
    ax = axes[i]
    year_data = monthly_counts[monthly_counts.index.year == year]
    year_data.index = year_data.index.strftime('%b')
    
    # Plot the data
    bars = year_data.plot(kind="bar", ax=ax)
    
    # Add labels on top of each bar **
    for container in ax.containers:
        ax.bar_label(container, fontsize=8, padding=3)
    
    # Adjust the Y-axis to make space for the labels
    ax.margins(y=0.1)
    
    # Set the title and labels for each subplot
    ax.set_title(f"Year {year}")
    ax.set_xlabel(None)
    ax.set_ylabel("Number of Articles")
    ax.tick_params(axis='x', rotation=45)

# Hide any unused subplots in the grid
for i in range(n_years, len(axes)):
    axes[i].axis('off')

fig.suptitle("Number of NBC Articles per Month by Year", fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.show()

# %%
# --- 1. Load news content data ---
df = pd.read_csv("data/ingestion/news/nbc_articles_with_content_official.csv")  
print("Loaded rows:", len(df))

# --- 2. Preprocess text in 'content' column ---
df_proc, col = textkit.preprocess_text_df(
    df,
    text_col="content",
    min_tokens=0,   # keep all rows
    use_pos=False   # faster, no POS tagging for news
)

# --- 3. Add word counts ---
textkit.add_word_count(df_proc, text_col=col, out_col="word_count")
average_length = df_proc["word_count"].mean()
print("Average word count:", average_length)

# --- 4. Show distribution plot ---
textkit.plot_wordcount_distribution(
    df_proc["word_count"], 
    title="Distribution of Article Word Counts"
)

# --- 5. Keyword frequency ---
stopwords = textkit.build_stopwords(
    extra={"says","study","company","could","new","year","next", "said", "like", "would", "said" , "would", "also", "like", "think", "going", "time", "one", "first", "last", "know", "get"}
)
top20 = textkit.keyword_frequency(df_proc["content"], stopword_set=stopwords, topn=20)

print("Top 20 Most Frequent Keywords:")
for _, row in top20.iterrows():
    print(f"- {row['word']}: {row['freq']}")

# --- 6. WordCloud ---
wc = textkit.generate_wordcloud(
    df_proc["content"], 
    stopword_set=stopwords,
    width=1000, height=500, 
    background_color="white",
    colormap="viridis", 
    max_words=100
)
textkit.plot_wordcloud(wc, title="Most Frequent Words in Articles")
# Out:
# Loaded rows: 5925
# Average word count: 990.604388185654
# Top 20 Most Frequent Keywords:
# - space: 19900
# - musk: 16579
# - trump: 16129
# - people: 11820
# - nasa: 9839
# - president: 9568
# - tesla: 9203
# - spacex: 8893
# - station: 7902
# - launch: 7142
# - two: 6752
# - news: 6603
# - well: 6550
# - back: 6254
# - years: 6119
# - twitter: 6075
# - government: 5635
# - even: 5619
# - right: 5602
# - make: 5564

# %%
df = pd.read_csv("data/ingestion/news/articles_topics_top_terms.csv")
df
# Out:
#    topic                                          top_terms
# 0      0  musk, twitter, company, x, platform, medium, u...
# 1      1  space, nasa, company, moon, mars, rocket, prog...
# 2      2  trump, government, president, administration, ...
# 3      3  president, state, campaign, election, video, o...
# 4      4  tesla, car, vehicle, company, model, battery, ...
# 5      5  space, spacex, station, nasa, rocket, launch, ...
# 6      6  city, home, child, science, man, research, sto...
# 7      7  space, satellite, mission, earth, launch, air,...
# 8      8  plane, flight, pilot, air, company, system, pa...
# 9      9  trump, president, kristen, welker, donald, bil...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Count distribution by category
df = pd.read_csv("data/ingestion/news/article_topic_distribution.csv")
distribution = df["dominant_topic"].value_counts()
print(distribution)

# Plot bar chart
plt.figure(figsize=(8,4))
ax = distribution.plot(kind="bar", color="skyblue", edgecolor="black")

plt.title("Distribution of Dominant Topics", fontsize=14)
plt.xlabel("Topic", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=45)

# Add counts above bars
for i, v in enumerate(distribution.values):
    ax.text(i, v + 0.5, str(v), ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# dominant_topic
# topic_4    1075
# topic_0     897
# topic_5     855
# topic_2     832
# topic_1     616
# topic_6     547
# topic_3     305
# topic_8     286
# topic_9     274
# topic_7     187
# Name: count, dtype: int64

# %% [markdown]
# ### 3. DATA TWEETS

# %%
# 1) Load raw tweets
CSV_PATH = "data/ingestion/tweets/all_musk_posts.csv" 
df_raw = pd.read_csv(CSV_PATH, low_memory=False)

# 2) Clean & keep short rows out (auto-detect fullText/text)
df_clean, detected_col = tk.preprocess_text_df(
    df_raw,
    candidates=("fullText", "text"),
    min_tokens=3,   # keep rows that have >=3 tokens after cleaning (like your old filter)
    use_pos=True    # POS-guided nouns; will gracefully fall back if tagger not available
)

# make an explicit 'text' column for exports
df_clean = df_clean.rename(columns={detected_col: "text"})

# 3) Save cleaned text (old: elon_musk_clean_tweets.csv)
df_clean[["text", "clean"]].to_csv("elon_musk_clean_tweets.csv", index=False, encoding="utf-8")
print("[SAVE] elon_musk_clean_tweets.csv")

# 4) TF-IDF (same params as your old code)
X, vocab, vec = tk.tfidf_matrix(
    df_clean["clean"],
    ngram_range=(1, 3),
    min_df=10,
    max_df=0.85
)
print("[TFIDF] shape:", X.shape)

# 5) NMF topics (same params as your old code)
n_topics = 8
nmf, W, H = tk.nmf_topics(X, n_topics=n_topics, random_state=42, init="nndsvd", max_iter=400)

# 6) Topics table + pretty print
topics_df = tk.topics_table(nmf, vocab, topn=12)
for k in range(nmf.n_components):
    terms = ", ".join(topics_df.query("topic==@k").sort_values("weight", ascending=False).head(12)["term"])
    print(f"Topic {k:02d}: {terms}")

# 7) Attach best topic to each tweet + save (old: elon_musk_clean_topics.csv / nmf_topics_terms.csv)
df_clean["topic_id"] = W.argmax(axis=1)
df_clean["topic_score"] = W.max(axis=1)

df_clean[["text", "clean", "topic_id", "topic_score"]].to_csv("elon_musk_clean_topics.csv", index=False, encoding="utf-8")
topics_df.to_csv("nmf_topics_terms.csv", index=False, encoding="utf-8")

print("[SAVE] elon_musk_clean_topics.csv  (text, clean, topic_id, topic_score)")
print("[SAVE] nmf_topics_terms.csv        (top terms per topic)")
# Out:
# [SAVE] elon_musk_clean_tweets.csv
# [TFIDF] shape: (19404, 2078)
# Topic 00: tesla, company, autopilot, tesla team, tesla model, software, owner, tesla owner, tesla autopilot, tesla car, supercharger, vehicle
# Topic 01: medium, legacy, legacy medium, propaganda, lie, machine, platform, medium propaganda, truth, news, medium lie, link
# Topic 02: launch, rocket, falcon, starship, flight, engine, starlink, space, spacex, dragon, earth, mar
# Topic 03: car, model, production, company, tesla car, month, week, cost, part, car company, software, model car
# Topic 04: twitter, government, world, account, money, company, speech, country, law, platform, america, party
# Topic 05: day, point, hour, post, night, person, news, house, end, end day, system, 100
# Topic 06: way, future, civilization, company, kid, money, platform, game, earth, level, need, tunnel
# Topic 07: team, lot, work, spacex, week, tesla team, spacex team, congrats, game, engineering, congratulation, lot work
# ...

# %%
import matplotlib.pyplot as plt

df = pd.read_csv("elon_musk_clean_topics.csv")
display(df)

# Count distribution
distribution = df["topic_id"].value_counts()

# Plot bar chart
plt.figure(figsize=(8,4))
ax = distribution.plot(kind="bar", color="skyblue", edgecolor="black")

plt.title("Distribution of Topic IDs", fontsize=14)
plt.xlabel("Topic ID", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.xticks(rotation=45)

# Add counts above bars
for i, v in enumerate(distribution.values):
    ax.text(i, v + 0.5, str(v), ha='center', va='bottom', fontsize=10, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
#                                                     text  \
# 0      RT @einarvollset: I read @paulg’s  “How to Mak...
# 1      RT @BillyM2k: dude bookmarks are an awesome tw...
# 2                             Event Horizon Balance Beam
# 3      RT @SpaceX: Watch Falcon 9 launch 54 Starlink ...
# 4      To get Blue Verified for $7/month, sign up via...
# ...                                                  ...
# 19399  Sterilizing minor children before the age of c...
# 19400  Extreme birth rate collapse is the biggest dan...
# 19401  @ajtourville @Tesla Rep. Khanna is a sensible ...
# 19402  The scale of spending on illegal immigration b...
# 19403  Shareholders should control company votes, not...
#
#                                          clean  topic_id  topic_score
# 0       wealth hacker painter mid twenty piece         4     0.002072
# 1        dude bookmark twitter feature twitter         4     0.158176
# ...

# %%
df = pd.read_csv("nmf_topics_terms.csv")
# distribution = df["dominant_topic"].value_counts()
display(df)
# Out:
#     topic            term    weight
# 0       0           tesla  4.349104
# 1       0         company  0.259703
# 2       0       autopilot  0.235500
# 3       0      tesla team  0.230978
# 4       0     tesla model  0.218866
# ..    ...             ...       ...
# 91      7        congrats  0.150833
# 92      7            game  0.143991
# 93      7     engineering  0.141739
# 94      7  congratulation  0.140692
# 95      7        lot work  0.122219
#
# [96 rows x 3 columns]
