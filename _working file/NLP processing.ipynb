# %% [markdown]
# ## Load Data

# %%
import pandas as pd

# %%
df_news = pd.read_csv("nbc_articles_cleaned.csv")

# %%
df_news
# Out:
#                                                   title  \
# 0     Cubs infielder Matt Shaw defends missing game ...
# 1     YouTube to start bringing back creators banned...
# 2     A trio of space weather satellites blast off t...
# 3     Trump administration rehires hundreds of feder...
# 4                 NASA introduces its newest astronauts
# ...                                                 ...
# 5920                    Good news, bad news for station
# 5921                  Documents detail shuttle what-ifs
# 5922         Model planes put high-tech eyes in the sky
# 5923              Shuttle probe follows a trail of data
# 5924           Analysis hints at shuttle’s last seconds
#
#                           date  \
# 0     2025-09-24T16:54:50.717Z
# 1     2025-09-24T16:54:08.647Z
# 2     2025-09-24T14:15:16.424Z
# 3     2025-09-24T13:35:34.846Z
# 4     2025-09-23T13:15:55.028Z
# ...                        ...
# 5920  2003-10-20T19:30:10.000Z
# 5921  2003-10-09T20:37:06.000Z
# 5922  2003-04-10T18:40:48.000Z
# 5923  2003-03-16T19:49:36.000Z
# 5924  2003-02-24T10:03:35.000Z
#
#                                                    link                author  \
# 0     https://www.nbcnews.com/news/us-news/cubs-matt...       Minyvonne Burke
# 1     https://www.nbcnews.com/tech/tech-news/youtube...  The Associated Press
# 2     https://www.nbcnews.com/science/science-news/t...  The Associated Press
# 3     https://www.nbcnews.com/politics/trump-adminis...  The Associated Press
# 4     https://www.nbcnews.com/science/science-news/n...  The Associated Press
# ...                                                 ...                   ...
# 5920             https://www.nbcnews.com/id/wbna3226810              NBC News
# 5921             https://www.nbcnews.com/id/wbna3077563           James Oberg
# 5922             https://www.nbcnews.com/id/wbna3077238         By Alan Boyle
# 5923             https://www.nbcnews.com/id/wbna3077573           James Oberg
# 5924             https://www.nbcnews.com/id/wbna3077579           James Oberg
#
#                                                 content  \
# 0     Chicago Cubs infielder Matt Shaw said he thoug...
# 1     YouTube will offer creators a way to rejoin th...
# 2     CAPE CANAVERAL, Fla. — A cluster of space weat...
# 3     MIAMI — Hundreds of federal employees who lost...
# 4     CAPE CANAVERAL, Fla. — NASA introduced its new...
# ...                                                 ...
# 5920  A Russian spacecraft filled in for the second ...
# 5921  An in-depth NASA study concludes that while th...
# 5922  NASA researchers are literally holding the fut...
# 5923  Investigators looking into the loss of the shu...
# 5924  New analysis of the garbled last 32 seconds of...
#
#                                                  tokens  \
# 0     ['chicago', 'cubs', 'infielder', 'matt', 'shaw...
# 1     ['youtube', 'offer', 'creator', 'way', 'rejoin...
# 2     ['cape', 'canaveral', 'fla.', 'cluster', 'spac...
# 3     ['miami', 'federal', 'employee', 'lose', 'job'...
# 4     ['cape', 'canaveral', 'fla.', 'nasa', 'introdu...
# ...                                                 ...
# 5920  ['russian', 'spacecraft', 'fill', 'second', 't...
# 5921  ['depth', 'nasa', 'study', 'conclude', 'crew',...
# 5922  ['nasa', 'researcher', 'literally', 'hold', 'f...
# 5923  ['investigator', 'look', 'loss', 'shuttle', 'c...
# 5924  ['new', 'analysis', 'garbled', 'second', 'radi...
#
#                                      tokens_with_ngrams  \
# 0     ['chicago', 'cubs', 'infielder', 'matt', 'shaw...
# 1     ['youtube', 'offer', 'creator', 'way', 'rejoin...
# 2     ['cape', 'canaveral', 'fla.', 'cluster', 'spac...
# 3     ['miami', 'federal', 'employee', 'lose', 'job'...
# 4     ['cape', 'canaveral', 'fla.', 'nasa', 'introdu...
# ...                                                 ...
# 5920  ['russian', 'spacecraft', 'fill', 'second', 't...
# 5921  ['depth', 'nasa', 'study', 'conclude', 'crew',...
# 5922  ['nasa', 'researcher', 'literally', 'hold', 'f...
# 5923  ['investigator', 'look', 'loss', 'shuttle', 'c...
# 5924  ['new', 'analysis', 'garbled', 'second', 'radi...
#
#                                              clean_text
# 0     chicago cubs infielder matt shaw think importa...
# 1     youtube offer creator way rejoin stream platfo...
# 2     cape canaveral fla. cluster space weather sate...
# 3     miami federal employee lose job elon_musk cost...
# 4     cape canaveral fla. nasa introduce new astrona...
# ...                                                 ...
# 5920  russian spacecraft fill second time u.s. shutt...
# 5921  depth nasa study conclude crew columbia able s...
# 5922  nasa researcher literally hold future aerial m...
# 5923  investigator look loss shuttle columbia seven ...
# 5924  new analysis garbled second radio signal space...
#
# [5925 rows x 8 columns]

# %%
df_news = df_news[df_news['date'].astype(str).str.contains('2023|2024|2025')]

# %%
cases = {
    'Tesla/Electric Car': ['Tesla', 'electric car', 'EV'],
    'SpaceX/NASA': ['SpaceX', 'NASA', 'rocket', 'astronaut']
}

# %%
def flag_cases(text):
    if pd.isna(text):  # Handle missing text gracefully
        return None
    # Iterate through the cases and check for keywords
    for case, keywords in cases.items():
        # Use a case-insensitive search for any of the keywords
        if any(keyword.lower() in text.lower() for keyword in keywords):
            return case
    # Return 'None' if no case matches
    return None

# %%
# Apply the function to the 'content' column to create the new 'flag_case' column
df_news['flag_case'] = df_news['content'].apply(flag_cases)

# %% [markdown]
# ## nltk sentiment analysis

# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# Download the VADER lexicon. This only needs to be done once.
try:
    nltk.download('vader_lexicon', quiet=True)
except Exception as e:
    print(f"Error downloading NLTK VADER lexicon: {e}")
    print("Please check your internet connection and try again.")
    exit()

# %%
# Initialize the VADER sentiment analyzer
sia = SentimentIntensityAnalyzer()

# Define a function to get the sentiment label from the compound score
def get_sentiment_label(text):
    if pd.isna(text):
        return 'Neutral'
    scores = sia.polarity_scores(str(text))
    compound_score = scores['compound']
    
    if compound_score >= 0.05:
        return 'Positive'
    elif compound_score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# %%
# Apply the function to the 'content' column to create a new sentiment column
df_news['sentiment_label'] = df_news['content'].apply(get_sentiment_label)
df_news['compound_score'] = df_news['content'].apply(lambda x: sia.polarity_scores(str(x))['compound'] if pd.notna(x) else 0)

# Display the first few rows to show the new columns
print("DataFrame with sentiment analysis results:")
print(df_news[['title', 'sentiment_label', 'compound_score']].head())

# Save the updated DataFrame to a new CSV file
output_file = "nbc_articles_with_sentiment.csv"
df_news.to_csv(output_file, index=False)
print(f"\nUpdated data saved to '{output_file}'")
# Out:
# DataFrame with sentiment analysis results:
#                                                title sentiment_label  \
# 0  Cubs infielder Matt Shaw defends missing game ...         Neutral
# 1  YouTube to start bringing back creators banned...        Negative
# 2  A trio of space weather satellites blast off t...        Positive
# 3  Trump administration rehires hundreds of feder...        Negative
# 4              NASA introduces its newest astronauts        Positive
#
#    compound_score
# 0          0.0478
# 1         -0.9927
# 2          0.9929
# 3         -0.8658
# 4          0.9843
#
# Updated data saved to 'nbc_articles_with_sentiment.csv'
